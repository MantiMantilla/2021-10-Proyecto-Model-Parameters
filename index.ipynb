# %% [markdown]
# **Tabla 1**. Ranking oficial según puntaje _CQ_

# %%
import pandas as pd
from IPython.display import display, HTML

df = pd.read_excel ("Hoja de Parámetros - Proyecto IIND 2103.xlsm", "Puntaje CQ", skiprows = 2, index_col = 0, usecols = "B:I")
display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Nombre</th>
#       <th>CQ 1</th>
#       <th>CQ 2</th>
#       <th>CQ 3</th>
#       <th>CQ 4</th>
#       <th>CQ 5</th>
#       <th>CQ 6</th>
#     </tr>
#     <tr>
#       <th>Ranking</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>ROGLIC Primoz</td>
#       <td>2171</td>
#       <td>2171</td>
#       <td>2073</td>
#       <td>3153</td>
#       <td>2830</td>
#       <td>3004</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>POGACAR Tadej</td>
#       <td>1173</td>
#       <td>1173</td>
#       <td>1431</td>
#       <td>2462</td>
#       <td>2642</td>
#       <td>2044</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>VAN AERT Wout</td>
#       <td>510</td>
#       <td>510</td>
# ...

# %% [markdown]
# **Tabla 2**. Puntaje oficial de cada evento para cada ciclista profesional.

# %%
df = pd.read_excel ("Hoja de Parámetros - Proyecto IIND 2103.xlsm", "Puntaje por Evento", skiprows = 2, index_col = 0, usecols = "B:I")
display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Nombre</th>
#       <th>PE 1</th>
#       <th>PE 2</th>
#       <th>PE 3</th>
#       <th>PE 4</th>
#       <th>PE 5</th>
#       <th>PE 6</th>
#     </tr>
#     <tr>
#       <th>Ranking</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>ROGLIC Primoz</td>
#       <td>88</td>
#       <td>114</td>
#       <td>23</td>
#       <td>45</td>
#       <td>39</td>
#       <td>118</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>POGACAR Tadej</td>
#       <td>229</td>
#       <td>99</td>
#       <td>4</td>
#       <td>5</td>
#       <td>21</td>
#       <td>76</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>VAN AERT Wout</td>
#       <td>24</td>
#       <td>117</td>
#       <td>25</td>
# ...

# %% [markdown]
# **Tabla 3**. Nacionalidad y equipo de cada ciclista profesional.

# %%
df = pd.read_excel ("Hoja de Parámetros - Proyecto IIND 2103.xlsm", "Nacionalidad y Equipo", skiprows = 1, index_col = 0, usecols = "B:E")
display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Nombre</th>
#       <th>Nacionalidad</th>
#       <th>Equipo</th>
#     </tr>
#     <tr>
#       <th>Ranking</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>ROGLIC Primoz</td>
#       <td>SLO</td>
#       <td>TJV</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>POGACAR Tadej</td>
#       <td>SLO</td>
#       <td>UAD</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>VAN AERT Wout</td>
#       <td>BEL</td>
#       <td>TJV</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>FUGLSANG Jakob</td>
#       <td>DEN</td>
#       <td>AST</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>VAN DER POEL Mathieu</td>
#       <td>NED</td>
#       <td>AFC</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>ALAPHILIPPE Julian</td>
#       <td>FRA</td>
# ...
